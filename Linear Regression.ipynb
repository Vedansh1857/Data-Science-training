# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([1.5,4.5,5.8,9.1,11,11.5])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
w0, w1 = np.random.rand(2)
print(w0,w1)
# Out:
# 0.3754253537181137 0.3337514461279807

# %%
lr = 0.001
epochs = 100
error = []

# %%
y_pred = []
for x1 in x:
    y_pred.append(w1*x1+w0)

# %%
plt.scatter(x,y,label="actual")
plt.plot(x,y_pred,c='r',label="predicted")
plt.legend()
plt.show()
